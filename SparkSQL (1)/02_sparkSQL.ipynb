-- %%
select * from sparksql_catelog.sparksql_schema.sales_managedtable limit 5

-- %% [markdown]
-- ### Creating a Py Dataframe from SQL Select query result set.

-- %%
%python
df_test = spark.sql('''SELECT * FROM sparksql_catelog.sparksql_schema.sales_managedtable limit 5;''')

display(df_test)
